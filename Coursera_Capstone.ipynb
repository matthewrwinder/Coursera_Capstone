# %%
# Capstone Project Notebook

# %%
### Final stage of the Coursera IBM Data Science Professional Certificate

# %% [markdown]
# This Notebook will capture the analysis and visualisation ideally confirming my understanding and ability to apply the course contents.

# %%
import pandas as pd
import numpy as np

sample = {'Name': ['Matt','John'], 'Age': [42,38]}
df=pd.DataFrame(data=sample)
df
# Out:
#    Name  Age
# 0  Matt   42
# 1  John   38

# %%
print ('Hello Capstone Project Course')
# Out:
# Hello Capstone Project Course
